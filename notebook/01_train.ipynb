# %% [markdown]
# Training YOLOv8 Model

# %%
# === Install YOLOv8 ===
# !pip install ultralytics --upgrade

# === Check YOLO version ===
# !yolo version

# Uncomment the following lines ONLY if you are running this notebook on Google Colab and your dataset is stored in Google Drive.
# from google.colab import drive
# drive.mount('/content/drive')

# === Train YOLOv8  Add your .yaml file's path below === 
# !yolo detect train data="/content/drive/MyDrive/Number_Plate_Detection/data.yaml" \ 
    model=yolov8n.pt \
    epochs=50 \
    imgsz=640 \
    batch=16 \
    name=number_plate_yolov8
