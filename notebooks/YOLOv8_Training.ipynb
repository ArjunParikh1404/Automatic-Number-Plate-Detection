# %% [markdown]
# Training YOLOv8 Model

# %%
# Step 1: Install YOLOv8
# !pip install ultralytics --upgrade

# Step 2: Check YOLO version
# !yolo version

# Step 3: Train YOLOv8  Add your .yaml file's path below 
# !yolo detect train data="/content/drive/MyDrive/Number_Plate_Detection/data.yaml" \ 
    model=yolov8n.pt \
    epochs=50 \
    imgsz=640 \
    batch=16 \
    name=number_plate_yolov8
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.5 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.3.228
# ...
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !cp /content/runs/detect/number_plate_yolov8/weights/best.pt /content/drive/MyDrive/Number_Plate_Detection/
